# %% [markdown]
# # Modules

# %%
import bin_packing as bp
import importlib

# %%
importlib.reload(bp);
bp.first_fit([1, 2, 3], 5)
# Out:
# [3, 3]

# %% [markdown]
# ## Exercise
#
# - Put the efficiency calculation part of the code in a separate function.
# - Put the plotting code in a separate function. Optionally: program a way for the user to choose a type of data visualisation.
# - Import bin_packing in the notebook, and call your 3 functions to produce the resulting graphs.

# %% [markdown]
# ## Example solution
#
# I've split up different tasks into a few more smaller functions to keep my code structured and modular: each function does one specific sub-task.
#
# A few notes:
#
# - The `labels` argument worked this time for `boxplot()`; this will depend on what version of matplotlib you are using (use `tick_labels` after version 3.9).
# - `[str(m) for m in methods]` is necessary to make sure that `None` appears correctly as a label.

# %%
importlib.reload(bp);

# Using some different values from the defaults
bp.compare_methods(N_sets=5000, bin_size=40)
